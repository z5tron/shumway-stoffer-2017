# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
print(plt.style.available)
plt.style.use('seaborn-notebook')
# Out:
# ['seaborn', 'seaborn-darkgrid', 'seaborn-white', 'seaborn-deep', 'seaborn-dark', 'seaborn-bright', 'seaborn-talk', 'seaborn-dark-palette', 'fivethirtyeight', 'classic', 'seaborn-whitegrid', 'Solarize_Light2', 'seaborn-notebook', 'seaborn-ticks', '_classic_test', 'fast', 'seaborn-muted', 'seaborn-pastel', 'bmh', 'dark_background', 'seaborn-paper', 'grayscale', 'tableau-colorblind10', 'seaborn-colorblind', 'seaborn-poster', 'ggplot']

# %%
jj = np.loadtxt('data/jj.dat')

# %%
plt.plot(jj)

# %%
globtemp = np.loadtxt('data/globtemp.dat')

# %%
plt.plot(globtemp, '-o')
